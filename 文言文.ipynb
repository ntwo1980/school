# %% [markdown]
# # 文言文实词

# %%
import io

def danzi(io, ch, pre_ch, next_ch):    # 实词、虚词、兼词
    sc ={"哀", "爱", "安", "按", "案", "昂", "傲",    # A
         "拔", "白", "败", "拜", "包", "报", "暴", "悲", "北", "备", "被", "倍", "背", "奔", "本", "逼", "彼", "比", "鄙", "蔽", "毕", "便", "遍", "表", "兵", "病", "并", "伯", "薄", "博", "步",  # B
         "裁", "苍", "操", "草", "策", "曾", "察", "尝", "长", "超", "彻", "陈", "乘", "称", "诚", "弛", "冲", "出", "除", "处", "垂", "差", "辞", "次", "刺", "从", "促", "错",   # C
         "达", "殆", "怠", "旦", "当", "道", "得", "定", "独", "度", "断", "对", "夺", "恶",    # D E
         "发", "伐", "法", "反", "犯", "方", "放", "非", "分", "奉", "服", "伏", "复", "负", "赋",    # F
         "盖", "更", "苟", "鼓", "固", "故", "顾", "寡", "观", "国", "归", "过",   # G
         "号", "好", "何", "恨", "厚", "还", "患", "胡", "会", "惠", "或",   # H
         "及", "极", "疾", "即", "济", "计", "既", "加", "假", "间", "简", "见", "将", "交", "竭", "结", "解", "矜", "尽", "进", "景", "竟", "就", "居", "举", "具", "俱", "聚", "决", "绝",   # J
         "堪", "克", "困",   # K
         "劳", "类", "怜", "临", "虑", "论",    # L
         "漫", "弥", "靡", "灭", "名", "明", "命", "莫", "谋",    # M
         "难", "乃", "内", "能", "逆",   # N
         "辟", "平", "迫",  # P
         "戚", "期", "奇", "启", "迁", "遣", "强", "请", "穷", "求", "取", "去", "全", "劝", "却",   # Q
         "任", "日", "如", "入", "若",   # R
         "塞", "色", "善", "稍", "少", "舍", "涉", "审", "甚", "生", "胜", "盛", "师", "施", "时", "识", "实", "食", "使", "始", "释", "恃", "市", "是", "适", "书", "疏", "孰", "属", "数", "率", "说", "顺", "私", "素", "速", "遂",   # S
         "汤", "涕", "通", "痛", "图", "徒", "退",   # T
         "亡", "王", "望", "微", "谓", "闻", "务",   # W
         "悉", "徙", "系", "狭", "鲜", "相", "向", "效", "谢", "信", "行", "形", "兴", "幸", "修", "徐", "许", "寻",   # X
         "延", "阳", "要", "业", "宜", "夷", "贻", "遗", "已", "异", "易", "诣", "益", "阴", "引", "盈", "余", "逾", "狱", "犹", "右", "语", "缘", "远", "愿", "云", #"一"   # Y
         "再", "造", "责", "贼", "章", "朝", "振", "知", "直", "止", "至", "志", "质", "治", "致", "质", "置", "中", "众", "周", "诸", "专", "传", "自", "走", "足", "卒", "族", "左", "坐", "作"}   # Z
    wb = {"临", "至", "白", "好", "志", "寻", "及", "日", "治", "止", "孰", "尝", "遣", "或", "实", "足", "倍", "乃", "阳", "拔", "备", "刺", "促",
          "断", "法", "苟", "惠", "平", "色", "徙", "周", "广", "犹", "昏", "王", "灭", "北", "会", "务", "还", "俱", "中"}     # 完毕
    xc = {"而", "何", "乎", "乃", "其", "且", "若", "所", "为", "焉", "也", "以", "因", "于", "与", "则", "者", "之"}   # 虚词
    jc = {"诸", "焉", "盍", "曷", "叵"}    # 兼词
    gzbd ={"察", "举", "荐", "征", "辟", "选", "封", "赏", "拜", "授", "除", "仕", "知", "补", "升", "迁", "拔", "擢", 
           "陟", "加", "晋", "兼", "领", "判", "摄", "守", "行", "署", "假", "权", "转", "调", "迁", "徙", "改", "出", 
           "贬", "谪", "放", "窜", "罢", "黜", "绌", "夺", "免"}   # 官职变动
    
    #if ch in sc.difference(wb).union(xc).union(jc) and (
    if ch in sc.difference(wb).union(jc) and (
        (ch != "将" or next_ch != "军")
    ):
        output.write("<b>")
        output.write(ch)
        output.write("</b>")
        return True
    else:
        return False
        
def fuzi(txt):  # 古今异义、官职变动、偏义复词
    ci = {"行李", "夫人", "东道主", "穷困", "偏袒", "夫人", "不顾", "有意", "无信", "婚姻", "山东",
          "河南", "河北", "非常", "细说", "至于", "浩荡", "流亡", "共事", "自由", "可怜", "处分", 
          "千万", "交通", "教训", "逢迎", "来信", "大家", "便利", "多谢", "同心", "依依", "其次", 
          "斯文", "徘徊", "白露", "茫然", "学者", "于是", "形容", "风流", "态度", "风骚", "偏僻", 
          "百年", "苦恨", "因为", "突出", "整顿", "等闲", "颜色", "老大", "向前", "春心", "惘然", 
          "可以", "然而", "养生", "以为", "博学", "爪牙", "夫人", "寄托", "众人", "从而", "不必", 
          "古文", "左右", "亲戚", "指示", "宣言", "约束", "所以", "明年", "以往", "因而", "不忍", 
          "前进", "春秋", "不幸", "成就", "操持", "相当", "亲近", "实在", "从容", "交接", "不行", 
          "周密", "方面", "下车", "窈窕", "童子", "果然", "羊角", "虽然", "无功", "成立", "上报", 
          "告诉", "区区", "无非", "天理", "行为", "慷慨", "气候", "面目", "其实", "智力", "祖父", 
          "故事", "成家", "志气", "强者", "记忆", "往往"}        # 古今异义

    pyfc = {"车骑", "父母", "公姥", "女子", "国家", "巷陌", "钟鼓", "钟磬", "少长", "契阔", "出入",
          "作息", "饥穰", "利害", "浅深", "死生", "往来", "虚实", "去来"}  # 偏义复词

    gzbd ={"告老", "谢官", "乞骸骨", "请老", "乞身", "致仕", "移病", "左迁", "左除", "左降", "左转"}   # 官职变动
    
    result = txt
    for ch in ci.union(gzbd).union(pyfc):
        result = result.replace(ch, "<b><i>" + ch + "</i></b>")
        
    return result

def outputChar(io, ch):
    if ch == "\n":
        output.write("</br>")
    else:
        output.write(ch)

article = """
汉三年，[110]项羽急围汉王荥阳，[111]汉王恐忧，与郦食其谋桡楚权。[112]食其曰：“昔汤伐桀，封其后于杞。[113]武王伐纣，封其后于宋。[114]今秦失德弃义，侵伐诸侯社稷，灭六国之后，使无立锥之地。[115]陛下诚能复立六国后世，[116]毕已受印，[117]此其君臣百姓必皆戴陛下之德，莫不乡风慕义，[118]愿为臣妾。[119]德义已行，陛下南乡称霸，[120]楚必敛衽而朝。”[121]汉王曰：“善。趣刻印，先生因行佩之矣。”[122]食其未行，张良从外来谒。[123]汉王方食，[124]曰：“子房前！[125]客有为我计桡楚权者。”具以郦生语告，曰：“于子房何如？”[126]良曰：“谁为陛下画此计者，陛下事去矣！”汉王曰：“何哉？”张良对曰：“臣请藉前箸为大王筹之！”[127]曰：“昔者汤伐桀而封其后于杞者，度能制桀之死命也。今陛下能制项籍之死命乎？”曰：“未能也。”[128]“其不可一也。[129]武王伐纣封其后于宋者，度能得纣之头也。今陛下能得项籍之头乎？”曰：“未能也。”“其不可二也。武王入殷，表商容之闾，释箕子之拘，封比干之墓。[130]今陛下能封圣人之墓，表贤者之闾，式智者之门乎？”[131]曰：“未能也。”“其不可三也。发钜桥之粟，散鹿台之钱，[132]以赐贫穷。今陛下能散府库以赐贫穷乎？”曰：“未能也。”“其不可四矣。殷事已毕，偃革为轩，[133]倒置干戈，覆以虎皮，[134]以示天下不复用兵。今陛下能偃武行文，不复用兵乎？”曰：“未能也。”“其不可五矣。休马华山之阳，[135]示以无所为。今陛下能休马无所用乎？”曰：“未能也。”“其不可六矣。放牛桃林之阴，[136]以示不复输积。[137]今陛下能放牛不复输积乎？”曰：“未能也。”“其不可七矣。且天下游士离其亲戚，弃坟墓，去故旧，从陛下游者，徒欲日夜望咫尺之地。[138]今复六国，立韩、魏、燕、赵、齐、楚之后，天下游士各归事其主，从其亲戚，反其故旧、坟墓，陛下与谁取天下乎？其不可八矣。且夫楚唯无彊，六国立者复桡而从之，[139]陛下焉得而臣之？[140]诚用客之谋，陛下事去矣！”汉王辍食吐哺，[141]骂曰：“竖儒几败而公事！”[142]令趣销印。
"""
# article = "改过不吝，从善如流

article = fuzi(article)

output = io.StringIO()
article_len = len(article)

for i in range(article_len):
    pre_ch = article[i-1] if i > 0 else None
    next_ch = article[i+1] if i < article_len - 1 else None
    ch = article[i]
    if not danzi(output, ch, pre_ch, next_ch):
        outputChar(output, ch)

print(output.getvalue())
# Out:
# </br>汉三年，[110]项羽急围汉王荥阳，[111]汉王恐忧，与郦<b>食</b>其<b>谋</b>桡楚权。[112]<b>食</b>其曰：“昔<b>汤</b><b>伐</b>桀，封其后于杞。[113]武王<b>伐</b>纣，封其后于宋。[114]今秦失德弃义，侵<b>伐</b><b>诸</b>侯社稷，灭六<b>国</b>之后，<b>使</b>无立锥之地。[115]陛下<b>诚</b><b>能</b><b>复</b>立六<b>国</b>后世，[116]<b>毕</b><b>已</b>受印，[117]此其君臣百姓必皆戴陛下之德，<b>莫</b>不乡风慕义，[118]<b>愿</b>为臣妾。[119]德义<b>已</b><b>行</b>，陛下南乡<b>称</b>霸，[120]楚必敛衽而<b>朝</b>。”[121]汉王曰：“<b>善</b>。趣刻印，先<b>生</b>因<b>行</b>佩之矣。”[122]<b>食</b>其未<b>行</b>，张良<b>从</b>外来谒。[123]汉王<b>方</b><b>食</b>，[124]曰：“子房前！[125]客有为我<b>计</b>桡楚权者。”<b>具</b>以郦<b>生</b><b>语</b>告，曰：“于子房<b>何</b><b>如</b>？”[126]良曰：“谁为陛下画此<b>计</b>者，陛下事<b>去</b>矣！”汉王曰：“<b>何</b>哉？”张良<b>对</b>曰：“臣<b>请</b>藉前箸为大王筹之！”[127]曰：“昔者<b>汤</b><b>伐</b>桀而封其后于杞者，<b>度</b><b>能</b>制桀之死<b>命</b>也。今陛下<b>能</b>制项籍之死<b>命</b>乎？”曰：“未<b>能</b>也。”[128]“其不可一也。[129]武王<b>伐</b>纣封其后于宋者，<b>度</b><b>能</b><b>得</b>纣之头也。今陛下<b>能</b><b>得</b>项籍之头乎？”曰：“未<b>能</b>也。”“其不可二也。武王<b>入</b>殷，<b>表</b>商容之闾，<b>释</b>箕子之拘，封<b>比</b>干之墓。[130]今陛下<b>能</b>封圣人之墓，<b>表</b>贤者之闾，式智者之门乎？”[131]曰：“未<b>能</b>也。”“其不可三也。<b>发</b>钜桥之粟，散鹿台之钱，
# ...

# %% [markdown]
# </br>汉三年，[110]项羽急围汉王荥阳，[111]汉王恐忧，与郦<b>食</b>其<b>谋</b>桡楚权。[112]<b>食</b>其曰：“昔<b>汤</b><b>伐</b>桀，封其后于杞。[113]武王<b>伐</b>纣，封其后于宋。[114]今秦失德弃义，侵<b>伐</b><b>诸</b>侯社稷，灭六<b>国</b>之后，<b>使</b>无立锥之地。[115]陛下<b>诚</b><b>能</b><b>复</b>立六<b>国</b>后世，[116]<b>毕</b><b>已</b>受印，[117]此其君臣百姓必皆戴陛下之德，<b>莫</b>不乡风慕义，[118]<b>愿</b>为臣妾。[119]德义<b>已</b><b>行</b>，陛下南乡<b>称</b>霸，[120]楚必敛衽而<b>朝</b>。”[121]汉王曰：“<b>善</b>。趣刻印，先<b>生</b>因<b>行</b>佩之矣。”[122]<b>食</b>其未<b>行</b>，张良<b>从</b>外来谒。[123]汉王<b>方</b><b>食</b>，[124]曰：“子房前！[125]客有为我<b>计</b>桡楚权者。”<b>具</b>以郦<b>生</b><b>语</b>告，曰：“于子房<b>何</b><b>如</b>？”[126]良曰：“谁为陛下画此<b>计</b>者，陛下事<b>去</b>矣！”汉王曰：“<b>何</b>哉？”张良<b>对</b>曰：“臣<b>请</b>藉前箸为大王筹之！”[127]曰：“昔者<b>汤</b><b>伐</b>桀而封其后于杞者，<b>度</b><b>能</b>制桀之死<b>命</b>也。今陛下<b>能</b>制项籍之死<b>命</b>乎？”曰：“未<b>能</b>也。”[128]“其不可一也。[129]武王<b>伐</b>纣封其后于宋者，<b>度</b><b>能</b><b>得</b>纣之头也。今陛下<b>能</b><b>得</b>项籍之头乎？”曰：“未<b>能</b>也。”“其不可二也。武王<b>入</b>殷，<b>表</b>商容之闾，<b>释</b>箕子之拘，封<b>比</b>干之墓。[130]今陛下<b>能</b>封圣人之墓，<b>表</b>贤者之闾，式智者之门乎？”[131]曰：“未<b>能</b>也。”“其不可三也。<b>发</b>钜桥之粟，散鹿台之钱，[132]以赐贫<b>穷</b>。今陛下<b>能</b>散府库以赐贫<b>穷</b>乎？”曰：“未<b>能</b>也。”“其不可四矣。殷事<b>已</b><b>毕</b>，偃革为轩，[133]倒<b>置</b>干戈，覆以虎皮，[134]以示天下不<b>复</b>用<b>兵</b>。今陛下<b>能</b>偃武<b>行</b>文，不<b>复</b>用<b>兵</b>乎？”曰：“未<b>能</b>也。”“其不可五矣。休马华山之阳，[135]示以无所为。今陛下<b>能</b>休马无所用乎？”曰：“未<b>能</b>也。”“其不可六矣。<b>放</b>牛桃林之<b>阴</b>，[136]以示不<b>复</b>输积。[137]今陛下<b>能</b><b>放</b>牛不<b>复</b>输积乎？”曰：“未<b>能</b>也。”“其不可七矣。且天下游士离其<b><i>亲<b>戚</b></i></b>，弃坟墓，<b>去</b><b>故</b>旧，<b>从</b>陛下游者，<b>徒</b>欲日夜<b>望</b>咫尺之地。[138]今<b>复</b>六<b>国</b>，立韩、魏、燕、赵、齐、楚之后，天下游士各<b>归</b>事其主，<b>从</b>其<b><i>亲<b>戚</b></i></b>，<b>反</b>其<b>故</b>旧、坟墓，陛下与谁<b>取</b>天下乎？其不可八矣。且夫楚唯无彊，六<b>国</b>立者<b>复</b>桡而<b>从</b>之，[139]陛下<b>焉</b><b>得</b>而臣之？[140]<b>诚</b>用客之<b>谋</b>，陛下事<b>去</b>矣！”汉王辍<b>食</b>吐哺，[141]骂曰：“竖儒几<b>败</b>而公事！”[142]令趣销印。</br>

# %% [markdown]
# # 古诗意象

# %%
import io

yixiang = {"芭蕉", "杜鹃", "子规", "寒蝉", "红豆", "鸿", "雁", "酒", "菊花", 
           "连理枝", "比翼鸟", "莲",  "杨", "柳", "絮", "梅", "南浦", "羌笛",
           "青鸟", "琴瑟", "水", "乌鸦", "梧桐", "蟋蟀", "燕", "猿", "猴", "月"}

poet = """新妆宜面下朱楼，
深锁春光一院愁。
行到中庭数花朵，
蜻蜓飞上玉搔头"""

for y in yixiang:
    poet = poet.replace(y, "**" + y + "**")
    
print(poet)
# Out:
# 新妆宜面下朱楼，
# 深锁春光一院愁。
# 行到中庭数花朵，
# 蜻蜓飞上玉搔头

# %% [markdown]
# 春江潮<b>水</b>连海平，海上明<b>月</b>共潮生。</br>滟滟随波千万里，何处春江无<b>月</b>明！</br>江流宛转绕芳甸，<b>月</b>照花林皆似霰。</br>空里流霜不觉飞，汀上白沙看不见。</br>江天一色无纤尘，皎皎空中孤<b>月</b>轮。</br>江畔何人初见<b>月</b>？江<b>月</b>何年初照人？</br>人生代代无穷已，江<b>月</b>年年望相似。</br>不知江<b>月</b>待何人，但见长江送流<b>水</b>。</br>白云一片去悠悠，青枫浦上不胜愁。</br>谁家今夜扁舟子？何处相思明<b>月</b>楼？</br>可怜楼上<b>月</b>徘徊，应照离人妆镜台。</br>玉户帘中卷不去，捣衣砧上拂还来。</br>此时相望不相闻，愿逐<b>月</b>华流照君。</br><b>鸿</b><b>雁</b>长飞光不度，鱼龙潜跃<b>水</b>成文。</br>昨夜闲潭梦落花，可怜春半不还家。</br>江<b>水</b>流春去欲尽，江潭落<b>月</b>复西斜。</br>斜<b>月</b>沉沉藏海雾，碣石潇湘无限路。</br>不知乘<b>月</b>几人归，落<b>月</b>摇情满江树。
